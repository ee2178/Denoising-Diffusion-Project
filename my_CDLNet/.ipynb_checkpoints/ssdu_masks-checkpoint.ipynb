# %%
import torch
import matplotlib.pyplot as plt
from mask import ssdu_mask_subsample
from mri_utils import make_acc_mask
# ------------------------------------------------------------------------------------
# Setup: create a simple undersampled k-space mask (Ω)
# Simulates a 2D mask with random undersampling at ~30% acceleration
# ------------------------------------------------------------------------------------

B, Nx, Ny = 1, 64, 64
acceleration = 4  # 4x accel

torch.manual_seed(42)

# Random undersampling mask — in practice this would come from your acquisition
# m_omega = torch.rand(B, 1, Nx, Ny) < acceleration
m_omega = make_acc_mask(
    [Nx, Ny],
    acceleration,
    acs_lines=10,
    dim=1,
    device = 'cpu',
)
print(f"Ω mask shape:         {m_omega.shape}")
print(f"Ω acquired points:    {m_omega[0, 0].sum().item()} / {Nx * Ny}")
# Out:
# Ω mask shape:         torch.Size([1, 1, 64, 64])
# Ω acquired points:    1472.0 / 4096

# %%
plt.imshow(m_omega.detach().cpu().numpy()[0,0])

# %%
m_lambda_rng, m_xi_rng = ssdu_mask_subsample(
    m_omega,
    rho=(0.4, 0.6),  # rho drawn uniformly from [0.4, 0.6] per batch element
    type="uniform_1D",
)

print(f"\n--- Random rho in [0.4, 0.6] ---")
for b in range(B):
    lam = m_lambda_rng[b, 0].sum().item()
    xi  = m_xi_rng[b, 0].sum().item()
    total = m_omega[b, 0].sum().item()
    print(f"  Batch {b}: Λ={lam}, Ξ={xi}, Ω={total}, rho≈{lam/total:.2f}")

# ------------------------------------------------------------------------------------
# Example 5: Plugging into a training loop (sketch)
# ------------------------------------------------------------------------------------

def ssdu_loss(model, kspace, m_omega, rho=0.5):
    """
    Self-supervised loss: train only on Ξ (loss mask) given Λ (input mask).
    """
    m_lambda, m_xi = ssdu_mask_subsample(m_omega, rho=rho, type="gaussian")

    # Zero out input so only Λ-sampled points are visible to the model
    kspace_input = kspace * m_lambda

    # Model reconstructs the full k-space
    kspace_pred = model(kspace_input, m_lambda)

    # Supervised only on Ξ points — never seen during input
    loss = ((kspace_pred - kspace) * m_xi).abs().pow(2).sum() / m_xi.sum()
    return loss
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/state/partition1/job-5896501/ipykernel_2493648/4215832637.py", line 1, in <module>
#     m_lambda_rng, m_xi_rng = ssdu_mask_subsample(
#   File "/scratch/ee2178/Denoising-Diffusion-Project/my_CDLNet/mask.py", line 137, in ssdu_mask_subsample
#   File "/scratch/ee2178/Denoising-Diffusion-Project/my_CDLNet/mask.py", line 113, in mask_subsample
#     m_lambda = torch.zeros_like(m_omega, dtype=torch.bool)
# ValueError: mask_subsample type "uniform_1D" not implemented.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/executing/executing.py", line 76, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
plt.imshow(m_lambda_acs.detach().cpu().numpy()[0,0])
