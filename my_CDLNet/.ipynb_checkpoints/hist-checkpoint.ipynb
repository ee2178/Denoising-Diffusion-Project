# %%
import torch 
import torch.fft as fft
import torch.nn as nn
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
smaps_fname = "../../datasets/fastmri_preprocessed/knee_coil_combined/pd/val/file1000323.h5"
kspace_fname = '../../datasets/fastmri/knee/multicoil_val/file1000323.h5'
slice = 17
with h5py.File(smaps_fname) as f:
    smaps = f['smaps'][:, :, :, :]
    smaps = smaps[slice, :, :, :]
    x = f['image'][slice, :, :]

with h5py.File(kspace_fname) as f:
    kspace = f['kspace'][slice, :, :, :]
    volume_kspace = f['kspace'][()]

# %%
# Make histograms out of coil combined image space
scale_fac = 5e3
mag_img = np.abs(x)
mag_img = mag_img[mag_img > 0].flatten() * scale_fac

plt.hist(mag_img, bins=100, color='lightblue', edgecolor='black')
plt.show()
