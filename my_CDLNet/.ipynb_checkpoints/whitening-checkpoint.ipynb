# %%
import torch 
import torch.fft as fft
import torch.nn as nn
import numpy as np
import h5py
import math
import json
import train
import os
import gc
import matplotlib.pyplot as plt

from mri_utils import mri_encoding, mri_decoding, walsh_smaps, fftc, ifftc, make_acc_mask, quant_complex, quant_tensor, espirit, mri_awgn
from nle import whiten 
from utils import load_data_knee
# Out:
# /home/ee2178/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/scratch/ee2178/miniconda3/envs/env/lib/python3.9/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
kspace, smaps, mask, image = load_data_knee(slice = 25, kspace_root = "../../datasets/fastmri/knee/multicoil_val",)

# %%
kspace_w, smaps_w, Sigma, zinv = whiten(ifftc(kspace), smaps)

# %%
# Inspect new coil combined image with kspace_w and smaps_w
image_w = torch.sum(smaps_w.conj()*kspace_w, dim=1, keepdim=True)
plt.imshow(image_w.abs().detach().cpu()[0,0], cmap = 'gray')

# %%
plt.imshow(zinv.abs().detach().cpu()[0,0], cmap = 'gray')

# %%
# Generate a mask
Ny, Nx = image.shape[-2], image.shape[-1]
mask = make_acc_mask(
        shape=(Ny, Nx),
        accel=6,
        acs_lines=20
    ).to(image.device)

plt.imshow(mask.detach().cpu()[0,0])

# %%
x_w, smaps_w, Sigma, zinv = whiten(ifftc(mask*kspace), smaps, mask = mask)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 x_w, smaps_w, Sigma, zinv = whiten(ifftc(kspace[:, :, kspace.shape[-2]//2-10:kspace.shape[-2]//2+10, kspace.shape[-1]//2-10:kspace.shape[-1]//2+10]), smaps, mask = mask)
#
# File /scratch/ee2178/Denoising-Diffusion-Project/my_CDLNet/nle.py:334, in whiten(x, smaps, Sigma, mask)
#     332     delta = _coil_combine(smaps_w, xs_w[0]).abs().amax(dim=(2, 3), keepdim=True)
#     333 else:
# --> 334     beta  = torch.stack(
#     335         [_coil_combine(smaps,   xi  ).abs().amax(dim=(2, 3)) for xi in xs],     dim=0
#     336     ).mean(0).unsqueeze(-1).unsqueeze(-1)
#     337     delta = torch.stack(
#     338         [_coil_combine(smaps_w, xi_w).abs().amax(dim=(2, 3)) for xi_w in xs_w], dim=0
#     339     ).mean(0).unsqueeze(-1).unsqueeze(-1)
#     341 sigma = beta / delta.clamp(min=eps)        # (B, 1, 1, 1)
#
# File /scratch/ee2178/Denoising-Diffusion-Project/my_CDLNet/nle.py:263, in _coil_combine(smaps, data)
#     259     """Sensitivity-weighted coil combination.  (B, C, H, W) -> (B, 1, H, W)"""
#     260     return (smaps.conj() * data).sum(dim=1, keepdim=True)
# --> 263 def whiten(
#     264     x:     Union[Tensor, List[Tensor]],
#     265     smaps: Optional[Tensor] = None,
#     266     Sigma: Optional[Tensor] = None,
#     267     mask: Optional[Tensor] = None,
#     268 ):
#     269     """
#     270     Whiten multicoil image-domain data.
#     271
#    (...)
#     295         "zinv"  – inverse normalisation map                (B, 1, H, W)
#     296     """
#     297     eps = _eps(x[0] if isinstance(x, (list, tuple)) else x)
#
# RuntimeError: The size of tensor a (372) must match the size of tensor b (20) at non-singleton dimension 3

# %%
acs_mask = torch.zeros_like(mask)

acs_mask[:, :, kspace.shape[-2]//2-10:kspace.shape[-2]//2+10, kspace.shape[-1]//2-10:kspace.shape[-1]//2+10] = 1

# %%
def extract_acs_region(mask: torch.Tensor):
    """
    Extract ACS (fully-sampled central k-space region) from a uniform mask.

    Parameters
    ----------
    mask : Tensor
        (H, W), (B, H, W), or (B, 1, H, W)
        binary sampling mask (1 = sampled)

    Returns
    -------
    acs_mask : Tensor with same shape as input (broadcasted per batch if needed)
    bbox     : (h_start, h_end, w_start, w_end)
    """

    # squeeze to 2D
    m = mask
    if m.dim() == 4:
        m2 = m[0, 0]
    elif m.dim() == 3:
        m2 = m[0]
    else:
        m2 = m

    H, W = m2.shape

    # find fully sampled rows/cols
    rows = torch.where(m2.sum(dim=1) == W)[0]
    cols = torch.where(m2.sum(dim=0) == H)[0]
    print(cols)

    if len(rows) == 0 or len(cols) == 0:
        raise ValueError("No fully sampled ACS region found.")

    # take contiguous central block
    h_start, h_end = rows[0].item(), rows[-1].item() + 1
    w_start, w_end = cols[0].item(), cols[-1].item() + 1

    acs = torch.zeros_like(m2)
    acs[h_start:h_end, w_start:w_end] = 1

    # restore shape
    if mask.dim() == 4:
        acs = acs.unsqueeze(0).unsqueeze(0).expand_as(mask)
    elif mask.dim() == 3:
        acs = acs.unsqueeze(0).expand_as(mask)
    else:
        acs = acs

    return acs, (h_start, h_end, w_start, w_end)

# %%
acs_mask = extract_acs_region(mask)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 acs_mask = extract_acs_region(mask)
#
# Cell In[36], line 33, in extract_acs_region(mask)
#      30 cols = torch.where(m2.sum(dim=-1) == H)[0]
#      32 if len(rows) == 0 or len(cols) == 0:
# ---> 33     raise ValueError("No fully sampled ACS region found.")
#      35 # take contiguous central block
#      36 h_start, h_end = rows[0].item(), rows[-1].item() + 1
#
# ValueError: No fully sampled ACS region found.

# %%
plt.imshow(mask[0,0].detach().cpu())

# %%
x_lowfreq = torch.sum(smaps.conj()*ifftc(acs_mask*kspace), dim = 1, keepdim = True)

plt.imshow(x_lowfreq[0,0].abs().detach().cpu())

# %%
# Inspect new coil combined image with kspace_w and smaps_w

image_w = torch.sum(smaps_w.conj()*x_w, dim=1, keepdim=True)
plt.imshow(Sigma.abs().detach().cpu()[0,0], cmap = 'gray')

# %%
# Sigma is an image of noise powers, pick the highest as it is consistent in the organ mask region. 
smap_root = "../../datasets/fastmri_preprocessed/knee_coil_combined/pd/train"
# Sweep over all fnames in kspace root
# record sigma_max for each sigma
# Form histogram of sigma_max's
sigma_hist = []
for root, dirs, files in os.walk(smap_root):
    # Take file and compute sigma
    for file in files:
        kspace, smaps, mask, gnd_truth = load_data_knee(kspace_fname = file, kspace_root = "../../datasets/fastmri/knee/multicoil_train", smap_root = smap_root)
        for s in range(12, 25):
            _, _, Sigma, _ = whiten(kspace[s:s+1, :, :, :], smaps[s:s+1, :, :, :])
            sigma_hist.append(Sigma.max())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       7 for root, dirs, files in os.walk(smap_root):
#       8     # Take file and compute sigma
#       9     for file in files:
# ---> 10         kspace, smaps, mask, gnd_truth = load_data_knee(kspace_fname = file, kspace_root = "../../datasets/fastmri/knee/multicoil_train", smap_root = smap_root)
#      11         for s in range(12, 25):
#      12             _, _, Sigma, _ = whiten(kspace[s:s+1, :, :, :], smaps[s:s+1, :, :, :])
#
# File /scratch/ee2178/Denoising-Diffusion-Project/my_CDLNet/utils.py:88, in load_data_knee(kspace_fname, slice, kspace_root, smap_root, device, scale_fac)
#      86 kspace = kspace.to(device)*scale_fac
#      87 # Compute the organ mask by summing over absolute value of smaps in the coil dimension
# ---> 88 mask = torch.sum(smaps.abs(), dim = 1, keepdim = True) > 0
#      90 # If slice is not none, only return that slice
#      91 if slice is not None:
#
# KeyboardInterrupt:

# %%
# plot histogram
# Create the histogram
plt.hist(sigma_hist, bins=30, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Noise Level')
plt.ylabel('Frequency')
plt.title('Histogram of KSpace Noise Levels (Validation Set)')

plt.show()

# %%
def make_coordinate_grid(H, W, device):
    y = torch.linspace(-1, 1, H, device=device)
    x = torch.linspace(-1, 1, W, device=device)
    yy, xx = torch.meshgrid(y, x, indexing='ij')
    return xx, yy  # shape (H, W)

def polynomial_basis(xx, yy, degree):
    """
    Returns list of basis terms up to given total degree.
    Example for degree=2:
    [1, x, y, x^2, xy, y^2]
    """
    basis = []
    for i in range(degree + 1):
        for j in range(degree + 1 - i):
            basis.append((xx ** i) * (yy ** j))
    return basis  # list of (H, W)

def complex_polynomial_field(
    shape,
    degree=3,
    temperature=0.1,
    centered=True
):
    """
    shape: (B, C, H, W)
    returns: complex tensor (B, C, H, W)
    """
    B, C, H, W = shape
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    xx, yy = make_coordinate_grid(H, W, device)
    basis = polynomial_basis(xx, yy, degree)
    K = len(basis)

    # stack basis → (K, H, W)
    basis_stack = torch.stack(basis, dim=0)

    # random coefficients per batch
    coeff_real = torch.randn(B, K, 1, 1, device=device)
    coeff_imag = torch.randn(B, K, 1, 1, device=device)

    # linear combination
    real = torch.sum(coeff_real * basis_stack.unsqueeze(0), dim=1, keepdim=True)
    imag = torch.sum(coeff_imag * basis_stack.unsqueeze(0), dim=1, keepdim=True)

    # normalize for stability
    def normalize(x):
        x = x - x.mean(dim=(-2, -1), keepdim=True)
        x = x / (x.std(dim=(-2, -1), keepdim=True) + 1e-8)
        return x

    real = normalize(real)
    imag = normalize(imag)

    field = real + 1j * imag  # (B,1,H,W)

    if centered:
        field = 1 + temperature * field
    else:
        field = temperature * field

    field = field.expand(-1, C, -1, -1)
    return field.to(torch.complex64)


def modulate_with_polynomial_field(
    x,
    degree=3,
    temperature=0.1,
    centered=True
):
    """
    x: complex tensor (B, C, H, W)
    """
    assert torch.is_complex(x)

    M = complex_polynomial_field(
        x.shape,
        degree=degree,
        temperature=temperature,
        centered=centered
    )

    return x * M

# %%
# Generate a sample 

M = complex_polynomial_field(
    smaps.shape,
    degree=3,
    temperature=0.1,
    centered=True
)

# Examine what it would look like if this polynomial field perturbed our smaps
x = torch.sum((M.to(smaps.device)*smaps).conj()*ifftc(kspace), dim = 1, keepdim = True)

plt.imshow(M.abs()[0,0].detach().cpu(), cmap = 'gray')
